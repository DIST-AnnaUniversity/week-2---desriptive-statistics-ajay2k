# %%
import pandas as pd
import io
import numpy
df = pd.read_csv('DDW_B18sc_3300_NIC_FINAL_STATE_TAMIL_NADU-2011.csv')

final = pd.DataFrame(df.StateCode)
print(final)
final.boxplot(figsize=(5,5),fontsize='8',grid=False)
q3,q1 = numpy.percentile(final,[75,25])
iqr = q3 - q1
lf=q1-1.5*iqr
uf=q3+1.5*iqr
print("Lower fence ",lf)
print("Upper fence ",uf)

final.describe()
# Out:
#     StateCode
# 0          33
# 1          34
# 2          35
# 3          36
# 4          37
# 5          38
# 6          39
# 7          40
# 8          41
# 9          42
# 10         43
# 11         44
# 12         45
# 13         46
# 14         47
# 15         48
# 16         49
# 17         50
# 18         51
# Lower fence  24.0
# Upper fence  60.0
#        StateCode
# count  19.000000
# mean   42.000000
# std     5.627314
# min    33.000000
# 25%    37.500000
# 50%    42.000000
# 75%    46.500000
# max    51.000000
